# %%
SELECT first_name,last_name,salary,
(SELECT AVG(salary)  
FROM 'Employee-Table.csv') AS Company_Average, 
(salary-(SELECT AVG(salary) 
FROM 'Employee-Table.csv')) AS salary_diff 
FROM 'Employee-Table.csv'
# Out:
#    first_name last_name  salary  Company_Average  salary_diff
# 0        John       Doe   75000          66150.0       8850.0
# 1        Jane     Smith   65000          66150.0      -1150.0
# 2        Mike   Johnson   60000          66150.0      -6150.0
# 3       Sarah     Brown   55000          66150.0     -11150.0
# 4       David       Lee   70000          66150.0       3850.0
# 5       Emily    Wilson   72000          66150.0       5850.0
# 6     Michael    Garcia   68000          66150.0       1850.0
# 7      Olivia  Martinez   61000          66150.0      -5150.0
# 8       James  Williams   59000          66150.0      -7150.0
# 9      Sophia    Taylor   72000          66150.0       5850.0
# 10     Daniel    Miller   75000          66150.0       8850.0
# 11        Ava  Anderson   66000          66150.0       -150.0
# 12    William     Moore   62000          66150.0      -4150.0
# 13       Ella     White   58000          66150.0      -8150.0
# 14  Alexander     Lopez   71000          66150.0       4850.0
# 15        Mia    Harris   73000          66150.0       6850.0
# 16      Henry     Clark   67000          66150.0        850.0
# 17      Grace     Lewis   63000          66150.0      -3150.0
# 18       Liam     Young   57000          66150.0      -9150.0
# 19      Chloe  Gonzalez   74000          66150.0       7850.0

# %%
SELECT* FROM 'Orders.csv'
# Out:
#       Row ID         OrderID  ... Discount    Profit
# 0          1  CA-2019-152156  ...     0.00   41.9136
# 1          2  CA-2019-152156  ...     0.00  219.5820
# 2          3  CA-2019-138688  ...     0.00    6.8714
# 3          4  US-2018-108966  ...     0.45 -383.0310
# 4          5  US-2018-108966  ...     0.20    2.5164
# ...      ...             ...  ...      ...       ...
# 9989    9990  CA-2017-110422  ...     0.20    4.1028
# 9990    9991  CA-2020-121258  ...     0.00   15.6332
# 9991    9992  CA-2020-121258  ...     0.20   19.3932
# 9992    9993  CA-2020-121258  ...     0.00   13.3200
# 9993    9994  CA-2020-119914  ...     0.00   72.9480
#
# [9994 rows x 21 columns]
